# %%
import os
import json
import pandas as pd
import traceback

# %%
pip install -U langchain-openai langchain

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    model="gpt-4o-mini",
    api_key="YOUR_API_KEY"
)

# %%
from langchain_openai import ChatOpenAI

# %%
from langchain.chat_models import ChatOpenAI

# %%
pip show langchain

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    model="gpt-4o-mini",
    api_key="YOUR_API_KEY"
)

# %%
from langchain.chat_models import ChatOpenAI

# %%
from langchain_openai import ChatOpenAI

print("Import successful!")

# %%
c

# %%
import langchain
print(langchain.__version__)

# %%
from langchain.chat_models import ChatOpenAI

# %%
import langchain
print(langchain.__version__)

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    model="gpt-4o-mini",
    api_key="your_api_key"
)

# %%
from langchain.chat_models import ChatOpenAI

# %%
from langchain.chat_models import ChatOpenAI

# %%
from langchain.chat_models import ChatOpenAI

# %%
from langchain.chat_models import ChatOpenAI

# %%
from langchain.chat_models import ChatOpenAI

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    model="gpt-4o-mini",
    api_key="YOUR_API_KEY"
)

# %%
from langchain.chat_models import ChatOpenAI

# %%
import os
import json
import pandas as pd
import traceback

# %%
from langchain.chat_models import ChatOpenAI
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from langchain.chat_models import ChatOpenAI
#
# ImportError: cannot import name 'ChatOpenAI' from 'langchain.chat_models' (c:\Users\user\anaconda3\Lib\site-packages\langchain\chat_models\__init__.py)

# %%
import os
import json
import pandas as pd
import traceback 
 import ChatOpenAI
# Out:
#   Cell In[5], line 5
#     import ChatOpenAI
#     ^
# IndentationError: unexpected indent

# %%
import os
import json
import pandas as pd
import traceback
# Out:
# Running cells with 'env (Python 3.13.9)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n env ipykernel --update-deps --force-reinstall'

# %%
'conda install -n env ipykernel --update-deps --force-reinstall'
# Out:
# Running cells with 'env (Python 3.13.9)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n env ipykernel --update-deps --force-reinstall'

# %%
conda install -n env ipykernel --update-deps --force-reinstall
# Out:
# Running cells with 'env (Python 3.13.9)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n env ipykernel --update-deps --force-reinstall'

# %%
conda install -n env ipykernel --update-deps --force-reinstall
# Out:
# 3 channel Terms of Service accepted
# Retrieving notices: done
#
# Note: you may need to restart the kernel to use updated packages.
# EnvironmentLocationNotFound: Not a conda environment: C:\Users\user\anaconda3\envs\env

# %%
c

# %%
from lanfchain.chat_models import ChatOpenAI
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from lanfchain.chat_models import ChatOpenAI
#
# ModuleNotFoundError: No module named 'lanfchain'

# %%
from langchain.chat_models import ChatOpenAI
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from langchain.chat_models import ChatOpenAI
#
# ImportError: cannot import name 'ChatOpenAI' from 'langchain.chat_models' (c:\Users\user\anaconda3\Lib\site-packages\langchain\chat_models\__init__.py)

# %%
c:\Users\user\anaconda3\Lib\site-packages\langchain\chat_models\__init__.py
# Out:
#   Cell In[4], line 1
#     c:\Users\user\anaconda3\Lib\site-packages\langchain\chat_models\__init__.py
#        ^
# SyntaxError: unexpected character after line continuation character

# %%
import langchain
print(langchain.__version__)
# Out:
# 1.3.11

# %%
from langchain_openai import ChatOpenAI

# %%
from langchain_openai import ChatOpenAI
print("Import successful!")
# Out:
# Import successful!

# %%
from langchain.chat_models import ChatOpenAI
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 from langchain.chat_models import ChatOpenAI
#
# ImportError: cannot import name 'ChatOpenAI' from 'langchain.chat_models' (c:\Users\user\anaconda3\Lib\site-packages\langchain\chat_models\__init__.py)

# %%
import os
import json
import pandas as pd
import traceback
from langchain.chat_models import ChatOpenAI
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[11], line 5
#       3 import pandas as pd
#       4 import traceback
# ----> 5 from langchain.chat_models import ChatOpenAI
#
# ImportError: cannot import name 'ChatOpenAI' from 'langchain.chat_models' (c:\Users\user\anaconda3\Lib\site-packages\langchain\chat_models\__init__.py)

# %%
import os
import json
import pandas as pd
import traceback
 import ChatOpenAI
# Out:
#   Cell In[12], line 5
#     import ChatOpenAI
#     ^
# IndentationError: unexpected indent

# %%
from langchain.chat_models import ChatOpenAI
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 from langchain.chat_models import ChatOpenAI
#
# ImportError: cannot import name 'ChatOpenAI' from 'langchain.chat_models' (c:\Users\user\anaconda3\Lib\site-packages\langchain\chat_models\__init__.py)

# %%
from langchain.chat_models import ChatOpenAI
# Out:
# Running cells with 'env (Python 3.13.9)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n env ipykernel --update-deps --force-reinstall'

# %%
from langchain.chat_models import ChatOpenAI
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from langchain.chat_models import ChatOpenAI
#
# ImportError: cannot import name 'ChatOpenAI' from 'langchain.chat_models' (c:\Users\user\anaconda3\Lib\site-packages\langchain\chat_models\__init__.py)

# %%
import os
import json
import pandas as pd

# %%
from Langchain.chat_models import ChatOpenAI
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from Langchain.chat_models import ChatOpenAI
#
# ModuleNotFoundError: No module named 'Langchain'

# %%
from Langchain.chat_models import ChatOpenAI
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from Langchain.chat_models import ChatOpenAI
#
# ModuleNotFoundError: No module named 'Langchain'

# %%
pip show langchain
# Out:
# Name: langchain
# Version: 1.3.11
# Summary: Building applications with LLMs through composability
# Home-page: https://docs.langchain.com/
# Author:
# Author-email:
# License: MIT
# Location: c:\Users\user\anaconda3\Lib\site-packages
# Requires: langchain-core, langgraph, pydantic
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain.chat_models import ChatOpenAI
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from langchain.chat_models import ChatOpenAI
#
# ImportError: cannot import name 'ChatOpenAI' from 'langchain.chat_models' (c:\Users\user\anaconda3\Lib\site-packages\langchain\chat_models\__init__.py)

# %%
from langchain.chat_models import ChatOpenAI
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from langchain.chat_models import ChatOpenAI
#
# ImportError: cannot import name 'ChatOpenAI' from 'langchain.chat_models' (c:\Users\user\anaconda3\Lib\site-packages\langchain\chat_models\__init__.py)

# %%
 import name 'ChatOpenAI' from 'langchain.chat_models'
# Out:
#   Cell In[9], line 1
#     import name 'ChatOpenAI' from 'langchain.chat_models'
#                 ^
# SyntaxError: invalid syntax

# %%
KEY=os.getenv("OPENAI_API_KEY")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 KEY=os.getenv("OPENAI_API_KEY")
#
# NameError: name 'os' is not defined

# %%
print(KEY)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(KEY)
#
# NameError: name 'KEY' is not defined

# %%
print(key)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(key)
#
# NameError: name 'key' is not defined

# %%
from env import load_dotenv
load_dotenv()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from env import load_dotenv
#       2 load_dotenv()
#
# ModuleNotFoundError: No module named 'env'

# %%
from env import load_dotenv
load_dotenv()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from env import load_dotenv
#       2 load_dotenv()
#
# ModuleNotFoundError: No module named 'env'

# %%
print(KEY)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print(KEY)
#
# NameError: name 'KEY' is not defined

# %%
from env import load_dotenv
load_dotenv()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from env import load_dotenv
#       2 load_dotenv()
#
# ModuleNotFoundError: No module named 'env'

# %%
from env import load_dotenv
load_dotenv()
# Out:
# Running cells with 'env (Python 3.13.9)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n env ipykernel --update-deps --force-reinstall'

# %%
from env import load_dotenv
load_dotenv()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from env import load_dotenv
#       2 load_dotenv()
#
# ModuleNotFoundError: No module named 'env'

# %%
from env import load_dotenv
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from env import load_dotenv
#
# ModuleNotFoundError: No module named 'env'

# %%
from dotenv import load_dotenv

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# False

# %%
from dotenv import load_dotenv
import os

load_dotenv()

api_key = os.getenv("OPENAI_API_KEY")
print(api_key)
# Out:
# None

# %%
from env import load_dotenv
load_dotenv()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from env import load_dotenv
#       2 load_dotenv()
#
# ModuleNotFoundError: No module named 'env'

# %%
print(KEY)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print(KEY)
#
# NameError: name 'KEY' is not defined

# %%
lm
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 lm
#
# NameError: name 'lm' is not defined

# %%
llm
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 llm
#
# NameError: name 'llm' is not defined

# %%
from langchain.llms import OpenAI
# from langchain.chat_models import ChatOpenAI
from langchain.prompts import promptTemplate
from langchain.chains import LLMChain
from langchain.chains import SequentialChains
from langchain.callbacks import get_openai_callback
# import os  
# import json
# import pandas as pd
# import traceback
# from dotenv import load_dotenv
# import pyPDF2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from langchain.llms import OpenAI
#       2 # from langchain.chat_models import ChatOpenAI
#       3 from langchain.prompts import promptTemplate
#
# ModuleNotFoundError: No module named 'langchain.llms'

# %%
quiz_genaration_prompt = PromptTemplate(
    input_variables=["text","number","subject","tone","response_json"],
    template=TEMPLATE
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 quiz_genaration_prompt = PromptTemplate(
#       2     input_variables=["text","number","subject","tone","response_json"],
#       3     template=TEMPLATE
#       4 )
#
# NameError: name 'PromptTemplate' is not defined

# %%
RESPONSE_JSON:
{ "quiz": [ { "question": "Question text", "options": { "A": "Option A", "B": "Option B", "C": "Option C", "D": "Option D" }, "correct_answer": "A" } ] }
# Out:
#   Cell In[5], line 1
#     RESPONSE_JSON:
#                   ^
# SyntaxError: invalid syntax

# %%
{ "quiz": [ { "question": "Question text", "options": { "A": "Option A", "B": "Option B", "C": "Option C", "D": "Option D" }, "correct_answer": "A" } ] }
# Out:
# {'quiz': [{'question': 'Question text',
#    'options': {'A': 'Option A',
#     'B': 'Option B',
#     'C': 'Option C',
#     'D': 'Option D'},
#    'correct_answer': 'A'}]}

# %%
{ "quiz": [ { "question": "Question text", "options": { "A": "Option A", "B": "Option B", "C": "Option C", "D": "Option D" }, "correct_answer": "A" } ] }
# Out:
# {'quiz': [{'question': 'Question text',
#    'options': {'A': 'Option A',
#     'B': 'Option B',
#     'C': 'Option C',
#     'D': 'Option D'},
#    'correct_answer': 'A'}]}

# %%
{ "quiz": [ { "question": "Question text", "options": { "A": "Option A", "B": "Option B", "C": "Option C", "D": "Option D" }, "correct_answer": "A" } ] }
{ "quiz": [ { "question": "Question text", "options": { "A": "Option A", "B": "Option B", "C": "Option C", "D": "Option D" }, "correct_answer": "A" } ] }
{ "quiz": [ { "question": "Question text", "options": { "A": "Option A", "B": "Option B", "C": "Option C", "D": "Option D" }, "correct_answer": "A" } ] }
{ "quiz": [ { "question": "Question text", "options": { "A": "Option A", "B": "Option B", "C": "Option C", "D": "Option D" }, "correct_answer": "A" } ] }
# Out:
# {'quiz': [{'question': 'Question text',
#    'options': {'A': 'Option A',
#     'B': 'Option B',
#     'C': 'Option C',
#     'D': 'Option D'},
#    'correct_answer': 'A'}]}

# %%
quiz_chain = LLMChain(llm=llm,verbase=true)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 quiz_chain = LLMChain(llm=llm,verbase=true)
#
# NameError: name 'LLMChain' is not defined

# %%
quiz_evalute_prompt=promptTemplate(
    input_variables=["text","number","subject","tone","response_json"],
# Out:
#   Cell In[12], line 2
#     input_variables=["text","number","subject","tone","response_json"],
#                                                                        ^
# _IncompleteInputError: incomplete input

# %%
review_Chain=LLMChain(llm=llm,prompt=quiz_evaluation_prompt,output_key="review",verbose=true)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 review_Chain=LLMChain(llm=llm,prompt=quiz_evaluation_prompt,output_key="review",verbose=true)
#
# NameError: name 'LLMChain' is not defined

# %%
review_Chain=LLMChain(llm=llm,prompt=quiz_evaluation_prompt,output_key="review",verbose=true)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 review_Chain=LLMChain(llm=llm,prompt=quiz_evaluation_prompt,output_key="review",verbose=true)
#
# NameError: name 'LLMChain' is not defined

# %%
generate_evaluate_chain=SequentialChain(chains=[quiz_chain, review_Chain], input_keys=["text", "number", "subject", "tone", "response_json"], output_keys=["review"], verbose=true)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 generate_evaluate_chain=SequentialChain(chains=[quiz_chain, review_Chain], input_keys=["text", "number", "subject", "tone", "response_json"], output_keys=["review"], verbose=true)
#
# NameError: name 'SequentialChain' is not defined

# %%
file_path=r"C:\Users\user\mcqgenerator\src\data.txt"

# %%
file_path
# Out:
# 'C:\\Users\\user\\mcqgenerator\\src\\data.txt'

# %%
with open(file_path, "r") as file:
    text = file.read()

# %%
print(text)
# Out:
# Machine learning (ML) is a field of study in artificial intelligence concerned with the development and study of statistical algorithms that can learn from data and generalize to unseen data, and thus perform tasks without being explicitly programmed.[1] Advances in the field of deep learning have allowed neural networks, a class of statistical algorithms, to surpass many previous machine learning approaches in performance.
#
# Statistics and mathematical optimisation methods compose the foundations of machine learning. Data mining is a related field of study, focusing on exploratory data analysis (EDA) through unsupervised learning.[3][4]
#
# From a theoretical viewpoint, probably approximately correct learning provides a mathematical and statistical framework for describing machine learning. Most traditional machine learning and deep learning algorithms can be described as empirical risk minimisation under this framework.
#
# History
# ...

# %%
json_dumps(RESPONSE_JSON)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 json_dumps(RESPONSE_JSON)
#
# NameError: name 'json_dumps' is not defined

# %%
json.dumps(RESPONSE_JSON)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 json.dumps(RESPONSE_JSON)
#
# NameError: name 'json' is not defined

# %%
with get_openai_callback() as cb:
    result = generate_evaluate_chain.run(text=text, number=5, subject="Science", tone="Informative", response_json=RESPONSE_JSON)
    print(result)
    print(f"Total Tokens: {cb.total_tokens}")
    print(f"Prompt Tokens: {cb.prompt_tokens}")
    print(f"Completion Tokens: {cb.completion_tokens}")
    print(f"Total Cost (USD): ${cb.total_cost:.6f}")

# %%
NUMBER=4
SUBJECT="machine learning"
TONE="simple"

# %%
with get_openai_callback() as cb:
    result = generate_evaluate_chain.run(text=text, number=5, subject="Science", tone="Informative", response_json=RESPONSE_JSON)
    print(result)
    print(f"Total Tokens: {cb.total_tokens}")
    print(f"Prompt Tokens: {cb.prompt_tokens}")
    print(f"Completion Tokens: {cb.completion_tokens}")
    print(f"Total Cost (USD): ${cb.total_cost:.6f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 with get_openai_callback() as cb:
#       2     result = generate_evaluate_chain.run(text=text, number=5, subject="Science", tone="Informative", response_json=RESPONSE_JSON)
#       3     print(result)
#
# NameError: name 'get_openai_callback' is not defined

# %%
response
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 response
#
# NameError: name 'response' is not defined

# %%
response.get("quiz", [])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 response.get("quiz", [])
#
# NameError: name 'response' is not defined

# %%
json.loads(quiz)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 json.loads(quiz)
#
# NameError: name 'json' is not defined

# %%
quiz_table_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 quiz_table_data
#
# NameError: name 'quiz_table_data' is not defined

# %%
from datetime import datetime
datetime.now().strftime('%Y-%m-%d_%H-%M-%S')
# Out:
# '2026-06-26_08-59-38'
